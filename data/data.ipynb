# %%
import pandas as pd

flights = pd.read_csv('C:\IIT Jodhpur\Inter IIT\Tinkering_Lab_Project\data\SCH-ZZ-20231127_213356.csv')
flights.head()

flight
# Out:
#        ScheduleID CarrierCode  FlightNumber     AircraftType  \
# 0  SCH-ZZ-7283355          ZZ          3417       Boeing 787
# 1  SCH-ZZ-8305184          ZZ          3083  Airbus A320 Neo
# 2  SCH-ZZ-7310425          ZZ          2943       Boeing 767
# 3  SCH-ZZ-3126325          ZZ          4211           ATR 72
# 4  SCH-ZZ-4285322          ZZ          4204       Boeing 787
#
#   AircraftTailNumber DepartureAirport ArrivalAirport DepartureTime  \
# 0            VT-6785              CNN            MAA          4:37
# 1            VT-3868              CCJ            MAA         22:42
# 2            VT-4386              AMD            HYD         13:55
# 3            VT-2017              GOI            DEL         17:01
# 4            VT-7218              HYD            DEL         12:05
#
#   ArrivalTime   StartDate  ... Monday Tuesday  Wednesday  Thursday  Friday  \
# 0       12:50  05/22/2024  ...      0       0          0         0       0
# ...
